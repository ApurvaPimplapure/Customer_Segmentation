# %%
#importing necessary libraries
import pandas as pd, numpy as np
from mlxtend.frequent_patterns import apriori, association_rules

#importing the dataset
CleanDataset = r'D:\SEM 4\DAB402 - CAPSTONE PROJECT\Cleansed_Dataset\OnlineRetail_Cleaned.csv'
Data_Cleaned = pd.read_csv(CleanDataset, index_col = 'InvoiceDate')
Data_Cleaned.index = pd.to_datetime(Data_Cleaned.index, format = '%m-%d-%Y %H:%M')


#converting the data into the standard form
Baskets = Data_Cleaned.loc[(Data_Cleaned['Quantity']>0) ,['InvoiceNo','Description','Quantity']]
Baskets = Baskets.groupby(['InvoiceNo','Description'])['Quantity'].sum().unstack(fill_value=0)
Baskets = (Baskets > 0)
Baskets
# Out:
# C:\Users\PC\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Description  *USB OFFICE MIRROR BALL  10 COLOUR SPACEBOY PEN  \
# InvoiceNo
# 536365                         False                   False
# 536366                         False                   False
# 536367                         False                   False
# 536368                         False                   False
# 536369                         False                   False
# ...                              ...                     ...
# 581583                         False                   False
# 581584                         False                   False
# 581585                         False                   False
# 581586                         False                   False
# 581587                         False                   False
#
# Description  12 COLOURED PARTY BALLOONS  12 DAISY PEGS IN WOOD BOX  \
# InvoiceNo
# 536365                            False                      False
# 536366                            False                      False
# 536367                            False                      False
# 536368                            False                      False
# 536369                            False                      False
# ...                                 ...                        ...
# 581583                            False                      False
# 581584                            False                      False
# 581585                            False                      False
# 581586                            False                      False
# 581587                            False                      False
#
# Description  12 EGG HOUSE PAINTED WOOD  12 HANGING EGGS HAND PAINTED  \
# InvoiceNo
# 536365                           False                         False
# 536366                           False                         False
# 536367                           False                         False
# 536368                           False                         False
# 536369                           False                         False
# ...                                ...                           ...
# 581583                           False                         False
# 581584                           False                         False
# 581585                           False                         False
# 581586                           False                         False
# 581587                           False                         False
#
# Description  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536365                                  False
# 536366                                  False
# 536367                                  False
# 536368                                  False
# 536369                                  False
# ...                                       ...
# 581583                                  False
# 581584                                  False
# 581585                                  False
# 581586                                  False
# 581587                                  False
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536365                                 False                          False
# 536366                                 False                          False
# 536367                                 False                          False
# 536368                                 False                          False
# 536369                                 False                          False
# ...                                      ...                            ...
# 581583                                 False                          False
# 581584                                 False                          False
# 581585                                 False                          False
# 581586                                 False                          False
# 581587                                 False                          False
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  ...  \
# InvoiceNo                                         ...
# 536365                                     False  ...
# 536366                                     False  ...
# 536367                                     False  ...
# 536368                                     False  ...
# 536369                                     False  ...
# ...                                          ...  ...
# 581583                                     False  ...
# 581584                                     False  ...
# 581585                                     False  ...
# 581586                                     False  ...
# 581587                                     False  ...
#
# Description  ZINC STAR T-LIGHT HOLDER  ZINC SWEETHEART SOAP DISH  \
# InvoiceNo
# 536365                          False                      False
# 536366                          False                      False
# 536367                          False                      False
# 536368                          False                      False
# 536369                          False                      False
# ...                               ...                        ...
# 581583                          False                      False
# 581584                          False                      False
# 581585                          False                      False
# 581586                          False                      False
# 581587                          False                      False
#
# Description  ZINC SWEETHEART WIRE LETTER RACK  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536365                                  False                           False
# 536366                                  False                           False
# 536367                                  False                           False
# 536368                                  False                           False
# 536369                                  False                           False
# ...                                       ...                             ...
# 581583                                  False                           False
# 581584                                  False                           False
# 581585                                  False                            True
# 581586                                  False                           False
# 581587                                  False                           False
#
# Description  ZINC T-LIGHT HOLDER STARS LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# InvoiceNo
# 536365                                 False                            False
# 536366                                 False                            False
# 536367                                 False                            False
# 536368                                 False                            False
# 536369                                 False                            False
# ...                                      ...                              ...
# 581583                                 False                            False
# 581584                                 False                            False
# 581585                                 False                            False
# 581586                                 False                            False
# 581587                                 False                            False
#
# Description  ZINC TOP 2 DOOR WOODEN SHELF  ZINC WILLIE WINKIE CANDLE STICK  \
# InvoiceNo
# 536365                              False                            False
# 536366                              False                            False
# 536367                              False                            False
# 536368                              False                            False
# 536369                              False                            False
# ...                                   ...                              ...
# 581583                              False                            False
# 581584                              False                            False
# 581585                              False                             True
# 581586                              False                            False
# 581587                              False                            False
#
# Description  ZINC WIRE KITCHEN ORGANISER  ZINC WIRE SWEETHEART LETTER TRAY
# InvoiceNo
# 536365                             False                             False
# 536366                             False                             False
# 536367                             False                             False
# 536368                             False                             False
# 536369                             False                             False
# ...                                  ...                               ...
# 581583                             False                             False
# 581584                             False                             False
# 581585                             False                             False
# 581586                             False                             False
# 581587                             False                             False
#
# [19694 rows x 3962 columns]

# %%
#finding frequent itemsets and association rules
frequent_itemsets = apriori(Baskets, min_support=0.031, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.65)
rules
# Out:
# C:\Users\PC\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                          antecedents                        consequents  \
# 0       (ALARM CLOCK BAKELIKE GREEN)         (ALARM CLOCK BAKELIKE RED)
# 1   (PINK REGENCY TEACUP AND SAUCER)  (GREEN REGENCY TEACUP AND SAUCER)
# 2  (GREEN REGENCY TEACUP AND SAUCER)  (ROSES REGENCY TEACUP AND SAUCER)
# 3  (ROSES REGENCY TEACUP AND SAUCER)  (GREEN REGENCY TEACUP AND SAUCER)
# 4          (JUMBO BAG PINK POLKADOT)          (JUMBO BAG RED RETROSPOT)
#
#    antecedent support  consequent support   support  confidence       lift  \
# 0            0.049761            0.053367  0.032497    0.653061  12.237286
# 1            0.038844            0.051437  0.032091    0.826144  16.061279
# 2            0.051437            0.054077  0.038946    0.757157  14.001361
# 3            0.054077            0.051437  0.038946    0.720188  14.001361
# 4            0.061846            0.106022  0.041840    0.676519   6.380921
#
#    leverage  conviction
# 0  0.029842    2.728532
# 1  0.030093    5.456020
# 2  0.036164    3.895202
# 3  0.036164    3.389999
# 4  0.035283    2.763617
